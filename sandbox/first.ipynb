# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
filePath = '../data/FRED_MD_20191113.csv'
df = pd.read_csv(filePath, index_col=0)
# print(df.head())
# df.info()
# df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 730 entries, Transform: to 9/1/2019
# Columns: 128 entries, RPI to VXOCLSx
# dtypes: float64(104), int64(24)
# memory usage: 735.7+ KB
#                 RPI       W875RX1  DPCERA3M086SBEA     CMRMTSPLx  \
# count    730.000000    730.000000       730.000000  7.290000e+02
# mean    8268.399536   7120.652329        58.965426  8.120609e+05
# std     4173.750281   3381.594147        30.679364  3.722682e+05
# min        5.000000      5.000000         5.000000  5.000000e+00
# 25%     4756.160500   4251.625000        32.253500  5.017033e+05
# 50%     7588.861500   6702.000000        53.265000  7.418618e+05
# 75%    11888.466500  10214.900000        88.311500  1.159614e+06
# max    17131.657000  14216.500000       121.448000  1.525005e+06
#
#              RETAILx      INDPRO     IPFPNSS     IPFINAL     IPCONGD  \
# count     730.000000  730.000000  730.000000  730.000000  730.000000
# mean   187784.472893   66.789941   69.895405   68.012579   79.127259
# std    151056.319005   27.083445   27.457166   27.341957   24.256604
# min         5.000000    5.000000    5.000000    5.000000    5.000000
# 25%     45505.946210   44.682500   45.985975   43.751600   61.546925
# 50%    151296.873950   63.263250   70.072950   67.746100   80.870500
# 75%    318860.250000   94.522525   98.988350   96.863425  102.142525
# max    526889.000000  110.551600  111.023800  108.641400  114.249000
#
#          IPDCONGD  ...  DSERRG3M086SBEA  CES0600000008  CES2000000008  \
# count  730.000000  ...       730.000000     730.000000     730.000000
# mean    73.940017  ...        54.050289      11.422219      13.278644
# std     32.382276  ...        33.520635       6.857961       7.624378
# min      5.000000  ...         6.000000       2.130000       2.450000
# 25%     47.481875  ...        19.244500       4.532500       6.085000
# 50%     67.299550  ...        52.109000      10.970000      12.915000
# 75%    107.751075  ...        82.045000      17.165000      19.215000
# max    125.766600  ...       118.060000      24.860000      28.580000
#
#        CES3000000008    UMCSENTx         MZMSL    DTCOLNVHFNM       DTCTHFNM  \
# count     730.000000  576.000000    730.000000     729.000000     729.000000
# mean       10.599096   86.375521   4104.181233  112976.140398  311316.972003
# std         6.248104   12.917638   4526.465093  112733.520171  317779.401780
# min         2.040000    2.000000      6.000000       6.000000       6.000000
# 25%         4.152500   77.150000    593.800000   10538.000000   32440.000000
# 50%        10.295000   90.200000   2052.550000   69688.000000  170832.280000
# 75%        16.117500   95.125000   6605.825000  230616.180000  681791.400000
# max        22.240000  112.000000  16587.500000  343472.980000  906492.750000
#
#             INVEST     VXOCLSx
# count   730.000000  688.000000
# mean   1014.357495   19.034214
# std    1033.051600    7.197840
# min       6.000000    1.000000
# 25%     167.178725   14.084150
# 50%     553.619800   17.490500
# 75%    1710.261850   22.378200
# max    3789.157800   67.151000
#
# [8 rows x 128 columns]

# %%
# Exploring the data set 
print(df.columns)
df.isnull().sum()

#time series plot
import matplotlib.pyplot as plt
df['RPI'].plot(title='Real Personal Income', figsize=(10, 6))
plt.show()
# Out:
# Index(['RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx', 'INDPRO',
#        'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD',
#        ...
#        'DSERRG3M086SBEA', 'CES0600000008', 'CES2000000008', 'CES3000000008',
#        'UMCSENTx', 'MZMSL', 'DTCOLNVHFNM', 'DTCTHFNM', 'INVEST', 'VXOCLSx'],
#       dtype='object', length=128)
